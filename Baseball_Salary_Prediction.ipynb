# %% [markdown]
# <a href="https://colab.research.google.com/github/aslyldrm/python-baseball-salary-prediction/blob/main/Baseball_Salary_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Baseball Salary Prediction**

# %% [markdown]
# # **Importing the libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv('hitters.csv')

# %%
dataset.drop(columns=['Division'], inplace=True)

# %%
X = dataset.iloc[:, :].values
y = dataset.loc[:, ['Salary']].values

# %% [markdown]
# # Taking care of missing data

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy='median')
imputer.fit(y)
y = imputer.transform(y)

# %%
X = np.delete(X, 18, axis=1)

# %%
X.shape
# Out:
# (322, 18)

# %% [markdown]
# # Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
values = [13,-1] #14

for i in values:
    X[:,i] = le.fit_transform(X[:,i])

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state=1)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()

X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor_lin_mul = LinearRegression()
regressor_lin_mul.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_mul = regressor_lin_mul.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred_mul.reshape(len(y_pred_mul),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 191.47  191.  ]
#  [ 308.73  450.  ]
#  [ 614.38  425.  ]
#  [ 804.21  425.  ]
#  [ 526.63  425.  ]
#  [ 639.6   425.  ]
#  [ 807.33  950.  ]
#  [1432.04 2412.5 ]
#  [1058.6  1925.57]
#  [ 280.73  172.  ]
#  [ 259.92  145.  ]
#  [ 853.09  425.  ]
#  [ -14.93  110.  ]
#  [ 243.2   225.  ]
#  [ 250.29  416.67]
#  [1120.09 1350.  ]
#  [ 680.05  425.  ]
#  [ 750.34  425.  ]
#  [  63.16   70.  ]
#  [ 483.    600.  ]
#  [ 241.62  400.  ]
#  [ 428.95  475.  ]
#  [ 199.39  245.  ]
#  [ 585.86  425.  ]
#  [ 691.09  365.  ]
#  [ 732.33  875.  ]
#  [ 587.36  750.  ]
#  [ 925.26  425.  ]
#  [ 373.92  120.  ]
#  [ 313.87  512.5 ]
#  [1090.19  425.  ]
#  [ 964.08 1670.  ]
#  [ 413.37  450.  ]
#  [ 491.47  595.  ]
#  [ 539.88  550.  ]
#  [ 754.53  700.  ]
#  [ 124.67  300.  ]
#  [ 466.01  550.  ]
#  [ 580.15  750.  ]
#  [ 358.59  140.  ]
#  [ 680.13 1000.  ]
#  [ 703.73  900.  ]
#  [ 837.17 1300.  ]
#  [ 654.94  425.  ]
#  [ 730.34  535.  ]
#  [ 394.47  326.67]
#  [ 766.47 1940.  ]
#  [ 394.18  300.  ]
#  [  76.77   75.  ]
#  [ 366.89  400.  ]
#  [ 215.64  362.5 ]
#  [ 392.28  431.5 ]
#  [ 140.32  375.  ]
#  [ 557.26  350.  ]
#  [ 148.84  160.  ]
#  [ 175.45  155.  ]
#  [ 849.76  733.33]
#  [ 394.66  200.  ]
#  [ 247.97   91.5 ]
#  [ 688.22 1043.33]
#  [ 594.17  700.  ]
#  [  34.2    70.  ]
#  [1294.7  1800.  ]
#  [ 266.65  385.  ]
#  [ 671.01 1100.  ]]

# %%
from sklearn.metrics import r2_score
r2_score_multiple_lin = r2_score(y_test, y_pred_mul)

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_rg = RandomForestRegressor(n_estimators = 25,min_samples_split = 5)
regressor_rg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(min_samples_split=5, n_estimators=25)

# %%
y_pred_rg = regressor_rg.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred_rg.reshape(len(y_pred_rg),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 196.46  191.  ]
#  [ 449.96  450.  ]
#  [ 425.    425.  ]
#  [ 425.    425.  ]
#  [ 425.    425.  ]
#  [ 425.    425.  ]
#  [ 977.07  950.  ]
#  [1840.25 2412.5 ]
#  [1837.7  1925.57]
#  [ 173.64  172.  ]
#  [ 144.    145.  ]
#  [ 499.72  425.  ]
#  [ 110.08  110.  ]
#  [ 221.56  225.  ]
#  [ 422.22  416.67]
#  [1358.62 1350.  ]
#  [ 425.    425.  ]
#  [ 425.    425.  ]
#  [  72.69   70.  ]
#  [ 598.1   600.  ]
#  [ 401.82  400.  ]
#  [ 475.36  475.  ]
#  [ 239.64  245.  ]
#  [ 425.    425.  ]
#  [ 366.44  365.  ]
#  [ 872.25  875.  ]
#  [ 749.75  750.  ]
#  [ 425.    425.  ]
#  [ 124.81  120.  ]
#  [ 517.85  512.5 ]
#  [ 475.96  425.  ]
#  [1559.55 1670.  ]
#  [ 453.58  450.  ]
#  [ 587.18  595.  ]
#  [ 545.11  550.  ]
#  [ 722.17  700.  ]
#  [ 303.21  300.  ]
#  [ 547.24  550.  ]
#  [ 750.15  750.  ]
#  [ 144.06  140.  ]
#  [1000.75 1000.  ]
#  [ 894.58  900.  ]
#  [1269.39 1300.  ]
#  [ 518.85  425.  ]
#  [ 633.33  535.  ]
#  [ 323.52  326.67]
#  [1786.29 1940.  ]
#  [ 305.55  300.  ]
#  [  73.75   75.  ]
#  [ 396.54  400.  ]
#  [ 352.3   362.5 ]
#  [ 419.94  431.5 ]
#  [ 360.79  375.  ]
#  [ 351.03  350.  ]
#  [ 155.    160.  ]
#  [ 146.1   155.  ]
#  [ 739.06  733.33]
#  [ 201.5   200.  ]
#  [  92.98   91.5 ]
#  [1019.39 1043.33]
#  [ 692.39  700.  ]
#  [  72.06   70.  ]
#  [1703.97 1800.  ]
#  [ 388.67  385.  ]
#  [1213.01 1100.  ]]

# %%
from sklearn.metrics import r2_score
re2_score_rfg = r2_score(y_test, y_pred_rg)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBRegressor
xgb_r = XGBRegressor()  #objective ='reg:linear', n_estimators = 10, seed = 123
xgb_r.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred_xcb = xgb_r.predict(X_test)
from sklearn.metrics import r2_score
r2_score_xcb_r = r2_score(y_test, pred_xcb)

# %%
r2_score_xcb_r
# Out:
# 0.985305132640575

# %% [markdown]
# # Support Vector Regression (SVR)

# %%
# from sklearn.preprocessing import StandardScaler
# sc_X = StandardScaler()

# X_train = sc_X.fit_transform(X_train)
# X_test = sc_X.transform(X_test)
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)


sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)
y_test = sc_y.transform(y_test)

# %%
from sklearn.svm import SVR
regressor_svr = SVR(kernel = 'rbf')
regressor_svr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_pred_svr = regressor_svr.predict(X_test)

# %%
r2_score_svr = r2_score(y_test, y_pred_svr)

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 1)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
y_pred_poly = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred_poly.reshape(len(y_pred_poly),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[-0.8  -0.8 ]
#  [-0.49 -0.13]
#  [ 0.3  -0.19]
#  [ 0.8  -0.19]
#  [ 0.07 -0.19]
#  [ 0.37 -0.19]
#  [ 0.8   1.18]
#  [ 2.43  4.99]
#  [ 1.46  3.72]
#  [-0.57 -0.85]
#  [-0.62 -0.92]
#  [ 0.92 -0.19]
#  [-1.34 -1.01]
#  [-0.67 -0.71]
#  [-0.65 -0.21]
#  [ 1.62  2.22]
#  [ 0.47 -0.19]
#  [ 0.66 -0.19]
#  [-1.13 -1.12]
#  [-0.04  0.26]
#  [-0.67 -0.26]
#  [-0.18 -0.06]
#  [-0.78 -0.66]
#  [ 0.23 -0.19]
#  [ 0.5  -0.35]
#  [ 0.61  0.98]
#  [ 0.23  0.65]
#  [ 1.11 -0.19]
#  [-0.32 -0.99]
#  [-0.48  0.04]
#  [ 1.54 -0.19]
#  [ 1.21  3.05]
#  [-0.22 -0.13]
#  [-0.02  0.25]
#  [ 0.11  0.13]
#  [ 0.67  0.52]
#  [-0.97 -0.52]
#  [-0.08  0.13]
#  [ 0.21  0.65]
#  [-0.36 -0.93]
#  [ 0.47  1.31]
#  [ 0.53  1.05]
#  [ 0.88  2.09]
#  [ 0.41 -0.19]
#  [ 0.6   0.09]
#  [-0.27 -0.45]
#  [ 0.7   3.75]
#  [-0.27 -0.52]
#  [-1.1  -1.1 ]
#  [-0.34 -0.26]
#  [-0.74 -0.35]
#  [-0.28 -0.17]
#  [-0.93 -0.32]
#  [ 0.15 -0.39]
#  [-0.91 -0.88]
#  [-0.84 -0.9 ]
#  [ 0.91  0.61]
#  [-0.27 -0.78]
#  [-0.65 -1.06]
#  [ 0.49  1.42]
#  [ 0.25  0.52]
#  [-1.21 -1.12]
#  [ 2.07  3.39]
#  [-0.6  -0.3 ]
#  [ 0.45  1.57]]

# %%
from sklearn.metrics import r2_score
r2_score_poly_reg = r2_score(y_test, y_pred_poly)

# %% [markdown]
# # Artifical Neural Network

# %%
import tensorflow as tf
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1))

# %%
ann.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mse'])

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8204 - mse: 0.8204
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7147 - mse: 0.7147
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7710 - mse: 0.7710
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7630 - mse: 0.7630
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8122 - mse: 0.8122
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5656 - mse: 0.5656
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5869 - mse: 0.5869
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5811 - mse: 0.5811
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5410 - mse: 0.5410
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5428 - mse: 0.5428
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5836 - mse: 0.5836
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5848 - mse: 0.5848
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5363 - mse: 0.5363
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6115 - mse: 0.6115
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5191 - mse: 0.5191
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4814 - mse: 0.4814
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4647 - mse: 0.4647
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5900 - mse: 0.5900
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6049 - mse: 0.6049
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5940 - mse: 0.5940
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4903 - mse: 0.4903
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5322 - mse: 0.5322
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5794 - mse: 0.5794
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5503 - mse: 0.5503
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4020 - mse: 0.4020
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5021 - mse: 0.5021
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5026 - mse: 0.5026
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4419 - mse: 0.4419
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5099 - mse: 0.5099
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4300 - mse: 0.4300
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4735 - mse: 0.4735
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5787 - mse: 0.5787
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4731 - mse: 0.4731
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4303 - mse: 0.4303
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3499 - mse: 0.3499
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3890 - mse: 0.3890
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3552 - mse: 0.3552
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3806 - mse: 0.3806
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4705 - mse: 0.4705
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3793 - mse: 0.3793
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4441 - mse: 0.4441
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3826 - mse: 0.3826
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4450 - mse: 0.4450
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3839 - mse: 0.3839
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3785 - mse: 0.3785
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4673 - mse: 0.4673
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4295 - mse: 0.4295
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4367 - mse: 0.4367
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3443 - mse: 0.3443
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4335 - mse: 0.4335
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4147 - mse: 0.4147
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3503 - mse: 0.3503
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3594 - mse: 0.3594
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3047 - mse: 0.3047
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3024 - mse: 0.3024
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4032 - mse: 0.4032
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4483 - mse: 0.4483
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3498 - mse: 0.3498
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4473 - mse: 0.4473
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3468 - mse: 0.3468
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3437 - mse: 0.3437
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4103 - mse: 0.4103
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3744 - mse: 0.3744
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4135 - mse: 0.4135
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3758 - mse: 0.3758
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3410 - mse: 0.3410
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4104 - mse: 0.4104
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4817 - mse: 0.4817
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3691 - mse: 0.3691
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3567 - mse: 0.3567
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3165 - mse: 0.3165
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2665 - mse: 0.2665
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3464 - mse: 0.3464
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3030 - mse: 0.3030
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3149 - mse: 0.3149
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2840 - mse: 0.2840
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3742 - mse: 0.3742
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2694 - mse: 0.2694
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4390 - mse: 0.4390
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3251 - mse: 0.3251
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4147 - mse: 0.4147
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2774 - mse: 0.2774
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3496 - mse: 0.3496
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3160 - mse: 0.3160
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3178 - mse: 0.3178
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3281 - mse: 0.3281
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3340 - mse: 0.3340
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2703 - mse: 0.2703
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3748 - mse: 0.3748
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2764 - mse: 0.2764
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2774 - mse: 0.2774
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3268 - mse: 0.3268
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4557 - mse: 0.4557
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2339 - mse: 0.2339
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3378 - mse: 0.3378
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2854 - mse: 0.2854
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3717 - mse: 0.3717
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2974 - mse: 0.2974
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2897 - mse: 0.2897
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3599 - mse: 0.3599

# %%
y_pred_ann = ann.predict(X_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
from sklearn.metrics import r2_score
r2_score_ann = r2_score(y_test, y_pred_ann)

# %% [markdown]
# # Results

# %%
print("R^2 score")
print("Support Vector Regression: " + str(r2_score_svr))
print("Polynomial Regression: " + str(r2_score_poly_reg))
print("Random Forest Regression: " + str(re2_score_rfg))
print("Multiple Linear regression: " + str(r2_score_multiple_lin))
print("XGBoost regressor: "+ str(r2_score_xcb_r))
print("ANN regressor: " + str(r2_score_ann))
# Out:
# R^2 score
# Support Vector Regression: 0.5980066348854449
# Polynomial Regression: 0.5699261814704946
# Random Forest Regression: 0.9729705861161405
# Multiple Linear regression: 0.5699261814704941
# XGBoost regressor: 0.985305132640575
# ANN regressor: 0.694348724656314
