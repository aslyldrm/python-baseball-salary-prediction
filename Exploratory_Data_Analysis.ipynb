# %% [markdown]
# <a href="https://colab.research.google.com/github/aslyldrm/python-baseball-salary-prediction/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv('hitters.csv')

# %% [markdown]
# # Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
values = [13,14,-1]


dataset['League'] = le.fit_transform(dataset['League'])
dataset['Division'] = le.fit_transform(dataset['Division'])
dataset['NewLeague'] = le.fit_transform(dataset['NewLeague'])

# %% [markdown]
# # EDA

# %%
dataset.describe()
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  322.000000  322.000000  322.000000  322.000000  322.000000  322.000000
# mean   380.928571  101.024845   10.770186   50.909938   48.027950   38.742236
# std    153.404981   46.454741    8.709037   26.024095   26.166895   21.639327
# min     16.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    255.250000   64.000000    4.000000   30.250000   28.000000   22.000000
# 50%    379.500000   96.000000    8.000000   48.000000   44.000000   35.000000
# 75%    512.000000  137.000000   16.000000   69.000000   64.750000   53.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years       CAtBat        CHits      CHmRun        CRuns  \
# count  322.000000    322.00000   322.000000  322.000000   322.000000
# mean     7.444099   2648.68323   717.571429   69.490683   358.795031
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AtBat      322 non-null    int64
#  1   Hits       322 non-null    int64
#  2   HmRun      322 non-null    int64
#  3   Runs       322 non-null    int64
#  4   RBI        322 non-null    int64
#  5   Walks      322 non-null    int64
#  6   Years      322 non-null    int64
#  7   CAtBat     322 non-null    int64
#  8   CHits      322 non-null    int64
#  9   CHmRun     322 non-null    int64
#  10  CRuns      322 non-null    int64
#  11  CRBI       322 non-null    int64
#  12  CWalks     322 non-null    int64
#  13  League     322 non-null    int64
#  14  Division   322 non-null    int64
#  15  PutOuts    322 non-null    int64
#  16  Assists    322 non-null    int64
#  17  Errors     322 non-null    int64
#  18  Salary     263 non-null    float64
#  19  NewLeague  322 non-null    int64
# ...

# %%
dataset.isnull().sum()
# Out:
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64

# %%
dataset.nunique()
# Out:
# AtBat        247
# Hits         144
# HmRun         36
# Runs          96
# RBI          103
# Walks         89
# Years         22
# CAtBat       314
# CHits        288
# CHmRun       146
# CRuns        261
# CRBI         262
# CWalks       248
# League         2
# Division       2
# PutOuts      232
# Assists      161
# Errors        29
# Salary       150
# NewLeague      2
# dtype: int64

# %%
sns.heatmap(dataset.corr(), annot=True)
plt.rcParams['figure.figsize'] = (50,40)
plt.show()

# %%
correlation = dataset.corr()
print(correlation['Salary'].sort_values(ascending=False))
# Out:
# Salary       1.000000
# CRBI         0.566966
# CRuns        0.562678
# CHits        0.548910
# CAtBat       0.526135
# CHmRun       0.524931
# CWalks       0.489822
# RBI          0.449457
# Walks        0.443867
# Hits         0.438675
# Runs         0.419859
# Years        0.400657
# AtBat        0.394771
# HmRun        0.343028
# PutOuts      0.300480
# Assists      0.025436
# NewLeague   -0.002834
# Errors      -0.005401
# League      -0.014282
# Division    -0.192514
# Name: Salary, dtype: float64
